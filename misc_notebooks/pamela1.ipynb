# %% [markdown]
# # Predicting preferred destination  based on taste and preference

# %% [markdown]
# The goal is to build a machine learning model that can predict hotel ratings based on customer reviews, budget, specific locations, and the type of residence. The dataset is scraped from TripAdvisor and it contains information about various hotels, including their ratings, reviews, amenities, pricing, geographical coordinates, and residence types (e.g., hotel, bed and breakfast, specialty lodging). By analyzing the text reviews along with these additional factors, the objective is to develop a model that can accurately predict the ratings of new, unseen hotels based on customer reviews, budget constraints, location preferences, and residence type.

# %% [markdown]
# Approach:
#
# Data Preprocessing: Clean and preprocess the text reviews by removing stopwords, punctuation, and performing tokenization. Convert the text data into a numerical representation suitable for modeling. Handle missing values, if any, in the budget, location, and residence type columns.
#
# Feature Engineering: Extract additional features from the dataset, such as review sentiment scores, review length, and any other relevant information. Engineer new features related to budget, location, and residence type, such as price range categories, geographical distance from landmarks, and one-hot encoding of residence types.
#
# Model Selection: Experiment with different supervised learning models, such as linear regression, decision trees, random forests, or neural networks, to find the best model for predicting hotel ratings considering customer reviews, budget, location, and residence type. Evaluate the models using appropriate evaluation metrics like mean squared error (MSE) or mean absolute error (MAE).
#
# Model Training and Evaluation: Split the dataset into training and testing sets. Train the selected model on the training set and evaluate its performance on the testing set. Fine-tune the model parameters to improve its accuracy. Perform cross-validation to assess the model's generalization capabilities.

# %%
import pandas as pd
import json
import glob
import re

# %%
def read_json_files(json_files):
    dfs = []
    for file in json_files:
        with open(file, encoding='utf-8') as f:
            json_data = json.load(f)
            df = pd.DataFrame(json_data)
            dfs.append(df)
    return pd.concat(dfs)

json_files = ['..\Data\drc.json', '..\Data\egypt.json', '..\Data\ethiopia.json',
                '..\Data\kenya.json', '..\Data\Madagascar.json', '..\Data\morocco.json',
                r'..\Data\nigeria.json', r'..\Data\rwanda.json', '..\Data\seychelles.json',
                r'..\Data\tanzania.json', r'..\Data\uganda.json', r'..\Data\namibia.json',
                '..\Data\south_africa.json', '..\Data\malawi.json', '..\Data\Senegal.json',
                '..\Data\zambia.json', '..\Data\Ghana.json', '..\Data\Botswana.json',
                '..\Data\capeverde.json']

df = read_json_files(json_files)

# %%
df
# Out:
#             id        type    category             subcategories  \
# 0      2704993  ATTRACTION  attraction          [Nature & Parks]
# 1      1536776  ATTRACTION  attraction          [Nature & Parks]
# 2     13203729  ATTRACTION  attraction  [Shopping, Food & Drink]
# 3      8661504       HOTEL       hotel       [Specialty Lodging]
# 4     10414108       HOTEL       hotel       [Specialty Lodging]
# ...        ...         ...         ...                       ...
# 1273  12216827       HOTEL       hotel       [Specialty Lodging]
# 1274  23200009       HOTEL       hotel       [Bed and Breakfast]
# 1275  13423426       HOTEL       hotel       [Bed and Breakfast]
# 1276  12957229       HOTEL       hotel       [Specialty Lodging]
# 1277  17789396       HOTEL       hotel       [Bed and Breakfast]
#
#                                                    name  \
# 0                                          Congoloisirs
# 1                                Okapi Wildlife Reserve
# 2                                  Marche Nouveau DAIPN
# 3                                    Bukima Tented Camp
# 4     Tchegera Island Tented Camp, Virunga National ...
# ...                                                 ...
# 1273                                  Casa Santos Pinto
# 1274  Kelly GuestHouse - Lovely Bedroom - Plateau Ci...
# 1275                                      Luz Esperanca
# 1276                                   Pensao Entre Nos
# 1277                                   Pensao Nossa Lar
#
#                       locationString  \
# 0                           Kinshasa
# 1                 Orientale Province
# 2                           Kinshasa
# 3     Rumangabo, North Kivu Province
# 4          Goma, North Kivu Province
# ...                              ...
# 1273   Curral das Vacas, Santo Antao
# 1274                 Praia, Santiago
# 1275          Pedra Badejo, Santiago
# 1276              Tarrafal, Santiago
# 1277                 Praia, Santiago
#
#                                             description  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     Just outside the Virunga National Park boundar...
# 4                                                  None
# ...                                                 ...
# 1273                                               None
# 1274                                               None
# 1275                                               None
# 1276                                               None
# 1277                                               None
#
#                                                   image  photoCount awards  \
# 0     https://media-cdn.tripadvisor.com/media/photo-...           9     []
# 1     https://media-cdn.tripadvisor.com/media/photo-...           3     []
# 2     https://media-cdn.tripadvisor.com/media/photo-...          12     []
# 3     https://media-cdn.tripadvisor.com/media/photo-...          79     []
# 4     https://media-cdn.tripadvisor.com/media/photo-...         109     []
# ...                                                 ...         ...    ...
# 1273                                               None           0     []
# 1274  https://media-cdn.tripadvisor.com/media/partne...           0     []
# 1275                                               None           0     []
# 1276                                               None           0     []
# 1277                                               None           0     []
#
#       ...  establishmentTypes  ownersTopReasons  localLangCode  \
# 0     ...                 NaN               NaN            NaN
# 1     ...                 NaN               NaN            NaN
# 2     ...                 NaN               NaN            NaN
# 3     ...                 NaN               NaN            NaN
# 4     ...                 NaN               NaN            NaN
# ...   ...                 ...               ...            ...
# 1273  ...                 NaN               NaN            NaN
# 1274  ...                 NaN               NaN            NaN
# 1275  ...                 NaN               NaN            NaN
# 1276  ...                 NaN               NaN            NaN
# 1277  ...                 NaN               NaN            NaN
#
#      guideFeaturedInCopy rentalDescriptions photos bedroomInfo bathroomInfo  \
# 0                    NaN                NaN    NaN         NaN          NaN
# 1                    NaN                NaN    NaN         NaN          NaN
# 2                    NaN                NaN    NaN         NaN          NaN
# 3                    NaN                NaN    NaN         NaN          NaN
# 4                    NaN                NaN    NaN         NaN          NaN
# ...                  ...                ...    ...         ...          ...
# 1273                 NaN                NaN    NaN         NaN          NaN
# 1274                 NaN                NaN    NaN         NaN          NaN
# 1275                 NaN                NaN    NaN         NaN          NaN
# 1276                 NaN                NaN    NaN         NaN          NaN
# 1277                 NaN                NaN    NaN         NaN          NaN
#
#      bathCount  baseDailyRate
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1273       NaN            NaN
# 1274       NaN            NaN
# 1275       NaN            NaN
# 1276       NaN            NaN
# 1277       NaN            NaN
#
# [35836 rows x 65 columns]

# %%
df.isnull().sum()
# Out:
# id                   0
# type                 0
# category             0
# subcategories     1339
# name                 0
#                  ...
# photos           34497
# bedroomInfo      34497
# bathroomInfo     34497
# bathCount        34497
# baseDailyRate    34568
# Length: 65, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'type', 'category', 'subcategories', 'name', 'locationString',
#        'description', 'image', 'photoCount', 'awards', 'rankingPosition',
#        'rating', 'rawRanking', 'phone', 'address', 'addressObj', 'localName',
#        'localAddress', 'email', 'latitude', 'longitude', 'webUrl', 'website',
#        'rankingString', 'rankingDenominator', 'neighborhoodLocations',
#        'nearestMetroStations', 'ancestorLocations', 'ratingHistogram',
#        'numberOfReviews', 'reviewTags', 'reviews', 'booking', 'offerGroup',
#        'subtype', 'hotelClass', 'amenities', 'numberOfRooms', 'priceLevel',
#        'priceRange', 'roomTips', 'checkInDate', 'checkOutDate', 'offers',
#        'hotelClassAttribution', 'isClosed', 'isLongClosed', 'openNowText',
#        'cuisines', 'mealTypes', 'dishes', 'features', 'dietaryRestrictions',
#        'hours', 'menuWebUrl', 'establishmentTypes', 'ownersTopReasons',
#        'localLangCode', 'guideFeaturedInCopy', 'rentalDescriptions', 'photos',
#        'bedroomInfo', 'bathroomInfo', 'bathCount', 'baseDailyRate'],
#       dtype='object')

# %%
df.reviewTags.value_counts()
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           21724
# [{'text': 'rooms', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               29
# [{'text': 'stay', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                21
# [{'text': 'guide', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               19
# [{'text': 'breakfast', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           16
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [{'text': 'large hotel', 'reviews': 3}, {'text': 'swimming pool', 'reviews': 9}, {'text': 'nice pool', 'reviews': 5}, {'text': 'nadia', 'reviews': 4}, {'text': 'africa', 'reviews': 12}, {'text': 'taxis', 'reviews': 4}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [{'text': 'fridge', 'reviews': 2}, {'text': 'meeting', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# [{'text': 'foot massage', 'reviews': 12}, {'text': 'massage room', 'reviews': 2}, {'text': 'kindness and respect', 'reviews': 2}, {'text': 'surrounded by beautiful gardens', 'reviews': 2}, {'text': 'muddy boots', 'reviews': 6}, {'text': 'outdoor sitting area', 'reviews': 2}, {'text': 'hot water bottles', 'reviews': 7}, {'text': 'national park', 'reviews': 8}, {'text': 'gorilla trekking', 'reviews': 9}, {'text': 'golden monkeys', 'reviews': 5}, {'text': 'lovely fireplace', 'reviews': 2}, {'text': 'stayed for nights', 'reviews': 3}, {'text': 'the entire staff', 'reviews': 2}, {'text': 'dining room', 'reviews': 3}, {'text': 'dian fossey', 'reviews': 2}, {'text': 'every evening', 'reviews': 2}, {'text': 'main building', 'reviews': 2}, {'text': 'grace', 'reviews': 6}, {'text': 'herbert', 'reviews': 4}, {'text': 'gato', 'reviews': 4}, {'text': 'priscilla', 'reviews': 6}, {'text': 'gloria', 'reviews': 2}, {'text': 'fund', 'reviews': 2}, {'text': 'chef', 'reviews': 7}, {'text': 'meals', 'reviews': 11}, {'text': 'lodge', 'reviews': 33}, {'text': 'dusk', 'reviews': 2}, {'text': 'jean', 'reviews': 2}, {'text': 'country', 'reviews': 4}, {'text': 'comfort', 'reviews': 3}]                                                                                                        1
# [{'text': 'can't wait to go back', 'reviews': 4}, {'text': 'a lot of fun', 'reviews': 3}, {'text': 'get away', 'reviews': 4}, {'text': 'service was excellent', 'reviews': 3}, {'text': 'hidden gem', 'reviews': 3}, {'text': 'world class', 'reviews': 2}, {'text': 'great amenities', 'reviews': 2}, {'text': 'food was amazing', 'reviews': 2}, {'text': 'high quality', 'reviews': 2}, {'text': 'conference room', 'reviews': 2}, {'text': 'perfect place', 'reviews': 2}, {'text': 'an hour and a half', 'reviews': 2}, {'text': 'the main road', 'reviews': 2}, {'text': 'shores of lake', 'reviews': 2}, {'text': 'top notch', 'reviews': 3}, {'text': 'multi course', 'reviews': 3}, {'text': 'akagera national park', 'reviews': 2}, {'text': 'attention to detail', 'reviews': 2}, {'text': 'rammed earth', 'reviews': 9}, {'text': 'other guests', 'reviews': 7}, {'text': 'communal dinner', 'reviews': 5}, {'text': 'course dinner', 'reviews': 4}, {'text': 'dining experience', 'reviews': 4}, {'text': 'paddle boards', 'reviews': 4}, {'text': 'great job', 'reviews': 3}, {'text': 'wonderful experience', 'reviews': 3}, {'text': 'incredible views', 'reviews': 3}, {'text': 'beautiful design', 'reviews': 3}, {'text': 'play tennis', 'reviews': 3}, {'text': 'staff were friendly', 'reviews': 3}]        1
# [{'text': 'carnival', 'reviews': 2}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: reviewTags, Length: 12450, dtype: int64

# %%
# Check null values and filter columns with more than 4000 null values
null_counts = df.isnull().sum()
columns_above_threshold = null_counts[null_counts > 10000].index

# Print the columns with more than 4000 null values
list(columns_above_threshold)
# Out:
# ['description',
#  'phone',
#  'localAddress',
#  'email',
#  'website',
#  'booking',
#  'offerGroup',
#  'subtype',
#  'hotelClass',
#  'numberOfRooms',
#  'priceLevel',
#  'priceRange',
#  'roomTips',
#  'checkInDate',
#  'checkOutDate',
#  'offers',
#  'hotelClassAttribution',
#  'isClosed',
#  'isLongClosed',
#  'openNowText',
#  'cuisines',
#  'mealTypes',
#  'dishes',
#  'features',
#  'dietaryRestrictions',
#  'hours',
#  'menuWebUrl',
#  'establishmentTypes',
#  'ownersTopReasons',
#  'localLangCode',
#  'guideFeaturedInCopy',
#  'rentalDescriptions',
#  'photos',
#  'bedroomInfo',
#  'bathroomInfo',
#  'bathCount',
#  'baseDailyRate']

# %%
# we will drop the following columns because they do not have any contribution to our objectives.
# some also contain too many null values to fill. 
cols_to_drop = columns_above_threshold

df.drop(columns=cols_to_drop, inplace=True)

# %%
list(df.columns)
# Out:
# ['id',
#  'type',
#  'category',
#  'subcategories',
#  'name',
#  'locationString',
#  'image',
#  'photoCount',
#  'awards',
#  'rankingPosition',
#  'rating',
#  'rawRanking',
#  'address',
#  'addressObj',
#  'localName',
#  'latitude',
#  'longitude',
#  'webUrl',
#  'rankingString',
#  'rankingDenominator',
#  'neighborhoodLocations',
#  'nearestMetroStations',
#  'ancestorLocations',
#  'ratingHistogram',
#  'numberOfReviews',
#  'reviewTags',
#  'reviews',
#  'amenities']

# %%
df[['locationString','rankingPosition','rawRanking','rankingString','rankingDenominator']]
# Out:
#                       locationString  rankingPosition  rawRanking  \
# 0                           Kinshasa             17.0    2.778074
# 1                 Orientale Province              1.0    2.751658
# 2                           Kinshasa             21.0    2.773659
# 3     Rumangabo, North Kivu Province              2.0    3.351389
# 4          Goma, North Kivu Province              1.0    3.464931
# ...                              ...              ...         ...
# 1273   Curral das Vacas, Santo Antao              NaN         NaN
# 1274                 Praia, Santiago              NaN         NaN
# 1275          Pedra Badejo, Santiago              NaN         NaN
# 1276              Tarrafal, Santiago              NaN         NaN
# 1277                 Praia, Santiago              NaN         NaN
#
#                                    rankingString rankingDenominator
# 0            #17 of 105 things to do in Kinshasa                105
# 1     #1 of 4 things to do in Orientale Province                  4
# 2            #21 of 105 things to do in Kinshasa                105
# 3         #2 of 3 Specialty lodging in Rumangabo                  3
# 4             #1 of 17 Specialty lodging in Goma                 17
# ...                                          ...                ...
# 1273                                        None               None
# 1274                                        None               None
# 1275                                        None               None
# 1276                                        None               None
# 1277                                        None               None
#
# [35836 rows x 5 columns]

# %%
df[['name','rankingString']]
# Out:
#                                                    name  \
# 0                                          Congoloisirs
# 1                                Okapi Wildlife Reserve
# 2                                  Marche Nouveau DAIPN
# 3                                    Bukima Tented Camp
# 4     Tchegera Island Tented Camp, Virunga National ...
# ...                                                 ...
# 1273                                  Casa Santos Pinto
# 1274  Kelly GuestHouse - Lovely Bedroom - Plateau Ci...
# 1275                                      Luz Esperanca
# 1276                                   Pensao Entre Nos
# 1277                                   Pensao Nossa Lar
#
#                                    rankingString
# 0            #17 of 105 things to do in Kinshasa
# 1     #1 of 4 things to do in Orientale Province
# 2            #21 of 105 things to do in Kinshasa
# 3         #2 of 3 Specialty lodging in Rumangabo
# 4             #1 of 17 Specialty lodging in Goma
# ...                                          ...
# 1273                                        None
# 1274                                        None
# 1275                                        None
# 1276                                        None
# 1277                                        None
#
# [35836 rows x 2 columns]

# %%
# Assuming your data is in a DataFrame called 'df' and the column is named 'rankingString'
# Create new columns
df['RankingType'] = ""
df['Location'] = ""
df['Numerator'] = ""
df['Denominator'] = ""

# Iterate through the rows and extract the information
for index, row in df.iterrows():
    # Check if the value is NaN
    if pd.isnull(row['rankingString']):
        continue
    
    # Use regular expressions to extract the information
    match = re.match(r'#(\d+)\s+of\s+(\d+)\s+(.*?)\s+in\s+(.*?)$', row['rankingString'])
    
    # Check if the match is successful
    if match:
        numerator = match.group(1)
        denominator = match.group(2)
        ranking_type = match.group(3)
        location = match.group(4)
        
        # Update the new columns
        df.at[index, 'RankingType'] = ranking_type
        df.at[index, 'Location'] = location
        df.at[index, 'Numerator'] = numerator
        df.at[index, 'Denominator'] = denominator

# %%
df.columns
# Out:
# Index(['id', 'type', 'category', 'subcategories', 'name', 'locationString',
#        'image', 'photoCount', 'awards', 'rankingPosition', 'rating',
#        'rawRanking', 'address', 'addressObj', 'localName', 'latitude',
#        'longitude', 'webUrl', 'rankingString', 'rankingDenominator',
#        'neighborhoodLocations', 'nearestMetroStations', 'ancestorLocations',
#        'ratingHistogram', 'numberOfReviews', 'reviewTags', 'reviews',
#        'amenities', 'RankingType', 'Location', 'Numerator', 'Denominator'],
#       dtype='object')

# %%
df.RankingType.value_counts()
# Out:
# B&Bs / Inns                  11523
# Specialty lodging             9814
# hotels                        4896
# things to do                  3306
# Boat Tours & Water Sports     1501
# Outdoor Activities             950
# Tours                          817
# B&B / Inn                      633
# Transportation                 608
# Shopping                       361
# Nightlife                      323
# Food & Drink                   304
# hotel                          299
# Spas & Wellness                247
# Classes & Workshops            133
# Fun & Games                     76
# Concerts & Shows                19
# Museums                         19
#                                  7
# Name: RankingType, dtype: int64

# %%
# Define the mappings to combine similar values
mappings = {
    'hotel': 'hotels',
    'B&B / Inn': 'B&Bs / Inns',
    
}

# Replace the values in the 'Ranking Type' column
df['RankingType'] = df['RankingType'].replace(mappings)

# %%
df.amenities
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                             [Restaurant, Mountain View]
# 4       [Multilingual Staff, Restaurant, Bar/Lounge, F...
#                               ...
# 1273    [Shuttle Bus Service, Restaurant, Bar/Lounge, ...
# 1274                                                   []
# 1275    [Kids Activities, Free parking, Airport transp...
# 1276    [Kids Activities, Free parking, Airport transp...
# 1277                                                   []
# Name: amenities, Length: 35836, dtype: object

# %%
null_values = df[df['amenities'].isnull()]
null_values
# Out:
#            id        type    category  \
# 0     2704993  ATTRACTION  attraction
# 1     1536776  ATTRACTION  attraction
# 2    13203729  ATTRACTION  attraction
# 6    19492774  ATTRACTION  attraction
# 7     4889528  ATTRACTION  attraction
# ..        ...         ...         ...
# 741  25810865  ATTRACTION  attraction
# 743  17504922  ATTRACTION  attraction
# 747  25416857  ATTRACTION  attraction
# 749  20282100  ATTRACTION  attraction
# 755  25772151  ATTRACTION  attraction
#
#                                          subcategories  \
# 0                                     [Nature & Parks]
# 1                                     [Nature & Parks]
# 2                             [Shopping, Food & Drink]
# 6                                 [Outdoor Activities]
# 7                                 [Sights & Landmarks]
# ..                                                 ...
# 741                                  [Spas & Wellness]
# 743  [Tours, Other, Boat Tours & Water Sports, Tran...
# 747                                            [Tours]
# 749  [Tours, Other, Transportation, Outdoor Activit...
# 755  [Food & Drink, Classes & Workshops, Tours, Oth...
#
#                                          name            locationString  \
# 0                                Congoloisirs                  Kinshasa
# 1                      Okapi Wildlife Reserve        Orientale Province
# 2                        Marche Nouveau DAIPN                  Kinshasa
# 6                                Cercle Elais                  Kinshasa
# 7                           Eglise CBFC-Gombe                  Kinshasa
# ..                                        ...                       ...
# 741          Renova Spa, RIU Palace Boa Vista          Rabil, Boa Vista
# 743                            Sea Turtle Sal  Santa Maria, Ilha do Sal
# 747                                Sidy Tours        Sal Rei, Boa Vista
# 749  Over Clauds Tours- Servico de Guia, Lda.      Mindelo, Sao Vicente
# 755                           Kriol Adventure                  Santiago
#
#                                                  image  photoCount awards  \
# 0    https://media-cdn.tripadvisor.com/media/photo-...           9     []
# 1    https://media-cdn.tripadvisor.com/media/photo-...           3     []
# 2    https://media-cdn.tripadvisor.com/media/photo-...          12     []
# 6    https://media-cdn.tripadvisor.com/media/photo-...           8     []
# 7    https://media-cdn.tripadvisor.com/media/photo-...          13     []
# ..                                                 ...         ...    ...
# 741  https://media-cdn.tripadvisor.com/media/photo-...           7     []
# 743  https://media-cdn.tripadvisor.com/media/photo-...           6     []
# 747                                               None           0     []
# 749  https://media-cdn.tripadvisor.com/media/photo-...           1     []
# 755  https://media-cdn.tripadvisor.com/media/photo-...           4     []
#
#      rankingPosition  ...                                  ancestorLocations  \
# 0               17.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# 1                1.0  ...  [{'id': '1536771', 'name': 'Orientale Province...
# 2               21.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# 6               14.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# 7                9.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# ..               ...  ...                                                ...
# 741              NaN  ...  [{'id': '13867343', 'name': 'Rabil', 'abbrevia...
# 743             13.0  ...  [{'id': '482848', 'name': 'Santa Maria', 'abbr...
# 747              NaN  ...  [{'id': '1185333', 'name': 'Sal Rei', 'abbrevi...
# 749              NaN  ...  [{'id': '482855', 'name': 'Mindelo', 'abbrevia...
# 755              NaN  ...  [{'id': '482850', 'name': 'Santiago', 'abbrevi...
#
#                                        ratingHistogram numberOfReviews  \
# 0    {'count1': 0, 'count2': 0, 'count3': 4, 'count...               9
# 1    {'count1': 0, 'count2': 0, 'count3': 0, 'count...               2
# 2    {'count1': 0, 'count2': 0, 'count3': 0, 'count...               3
# 6    {'count1': 1, 'count2': 0, 'count3': 0, 'count...               6
# 7    {'count1': 0, 'count2': 0, 'count3': 1, 'count...              11
# ..                                                 ...             ...
# 741  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 743  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               2
# 747  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 749  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 755  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
#
#                            reviewTags reviews  amenities        RankingType  \
# 0                                  []      []        NaN       things to do
# 1                                  []      []        NaN       things to do
# 2                                  []      []        NaN       things to do
# 6    [{'text': 'pool', 'reviews': 2}]      []        NaN       things to do
# 7                                  []      []        NaN             hotels
# ..                                ...     ...        ...                ...
# 741                                []      []        NaN  Specialty lodging
# 743                                []      []        NaN     Transportation
# 747                                []      []        NaN        B&Bs / Inns
# 749                                []      []        NaN  Specialty lodging
# 755                                []      []        NaN        B&Bs / Inns
#
#            Location Numerator Denominator
# 0      Cidade Velha         1           9
# 1             Praia         1          20
# 2         Boa Vista         4          30
# 6       Santa Maria         4          22
# 7    Ribeira Grande         1           7
# ..              ...       ...         ...
# 741        Gaborone        18         108
# 743     Santa Maria        13          27
# 747        Gaborone        21         125
# 749            Maun        48          81
# 755        Gaborone        26         125
#
# [9680 rows x 32 columns]

# %%
df['amenities'] = df['amenities'].apply(lambda x: tuple(x) if isinstance(x, list) else x)
grouped_counts = df[['name', 'amenities']].groupby('amenities').value_counts()

# %%
df
# Out:
#             id        type    category             subcategories  \
# 0      2704993  ATTRACTION  attraction          [Nature & Parks]
# 1      1536776  ATTRACTION  attraction          [Nature & Parks]
# 2     13203729  ATTRACTION  attraction  [Shopping, Food & Drink]
# 3      8661504       HOTEL       hotel       [Specialty Lodging]
# 4     10414108       HOTEL       hotel       [Specialty Lodging]
# ...        ...         ...         ...                       ...
# 1273  12216827       HOTEL       hotel       [Specialty Lodging]
# 1274  23200009       HOTEL       hotel       [Bed and Breakfast]
# 1275  13423426       HOTEL       hotel       [Bed and Breakfast]
# 1276  12957229       HOTEL       hotel       [Specialty Lodging]
# 1277  17789396       HOTEL       hotel       [Bed and Breakfast]
#
#                                                    name  \
# 0                                          Congoloisirs
# 1                                Okapi Wildlife Reserve
# 2                                  Marche Nouveau DAIPN
# 3                                    Bukima Tented Camp
# 4     Tchegera Island Tented Camp, Virunga National ...
# ...                                                 ...
# 1273                                  Casa Santos Pinto
# 1274  Kelly GuestHouse - Lovely Bedroom - Plateau Ci...
# 1275                                      Luz Esperanca
# 1276                                   Pensao Entre Nos
# 1277                                   Pensao Nossa Lar
#
#                       locationString  \
# 0                           Kinshasa
# 1                 Orientale Province
# 2                           Kinshasa
# 3     Rumangabo, North Kivu Province
# 4          Goma, North Kivu Province
# ...                              ...
# 1273   Curral das Vacas, Santo Antao
# 1274                 Praia, Santiago
# 1275          Pedra Badejo, Santiago
# 1276              Tarrafal, Santiago
# 1277                 Praia, Santiago
#
#                                                   image  photoCount awards  \
# 0     https://media-cdn.tripadvisor.com/media/photo-...           9     []
# 1     https://media-cdn.tripadvisor.com/media/photo-...           3     []
# 2     https://media-cdn.tripadvisor.com/media/photo-...          12     []
# 3     https://media-cdn.tripadvisor.com/media/photo-...          79     []
# 4     https://media-cdn.tripadvisor.com/media/photo-...         109     []
# ...                                                 ...         ...    ...
# 1273                                               None           0     []
# 1274  https://media-cdn.tripadvisor.com/media/partne...           0     []
# 1275                                               None           0     []
# 1276                                               None           0     []
# 1277                                               None           0     []
#
#       rankingPosition  ...                                  ancestorLocations  \
# 0                17.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# 1                 1.0  ...  [{'id': '1536771', 'name': 'Orientale Province...
# 2                21.0  ...  [{'id': '294187', 'name': 'Kinshasa', 'abbrevi...
# 3                 2.0  ...  [{'id': '3656749', 'name': 'Rumangabo', 'abbre...
# 4                 1.0  ...  [{'id': '303843', 'name': 'Goma', 'abbreviatio...
# ...               ...  ...                                                ...
# 1273              NaN  ...  [{'id': '12880045', 'name': 'Curral das Vacas'...
# 1274              NaN  ...  [{'id': '293775', 'name': 'Praia', 'abbreviati...
# 1275              NaN  ...  [{'id': '1601793', 'name': 'Pedra Badejo', 'ab...
# 1276              NaN  ...  [{'id': '482851', 'name': 'Tarrafal', 'abbrevi...
# 1277              NaN  ...  [{'id': '293775', 'name': 'Praia', 'abbreviati...
#
#                                         ratingHistogram numberOfReviews  \
# 0     {'count1': 0, 'count2': 0, 'count3': 4, 'count...               9
# 1     {'count1': 0, 'count2': 0, 'count3': 0, 'count...               2
# 2     {'count1': 0, 'count2': 0, 'count3': 0, 'count...               3
# 3     {'count1': 1, 'count2': 0, 'count3': 0, 'count...              34
# 4     {'count1': 0, 'count2': 0, 'count3': 1, 'count...              29
# ...                                                 ...             ...
# 1273  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 1274  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 1275  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 1276  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
# 1277  {'count1': 0, 'count2': 0, 'count3': 0, 'count...               0
#
#                                              reviewTags reviews  \
# 0                                                    []      []
# 1                                                    []      []
# 2                                                    []      []
# 3                                                    []      []
# 4     [{'text': 'gorilla trekking', 'reviews': 3}, {...      []
# ...                                                 ...     ...
# 1273                                                 []      []
# 1274                                                 []      []
# 1275                                                 []      []
# 1276                                                 []      []
# 1277                                                 []      []
#
#                                               amenities        RankingType  \
# 0                                                   NaN       things to do
# 1                                                   NaN       things to do
# 2                                                   NaN       things to do
# 3                           (Restaurant, Mountain View)       things to do
# 4     (Multilingual Staff, Restaurant, Bar/Lounge, F...        B&Bs / Inns
# ...                                                 ...                ...
# 1273  (Shuttle Bus Service, Restaurant, Bar/Lounge, ...  Specialty lodging
# 1274                                                 ()        B&Bs / Inns
# 1275  (Kids Activities, Free parking, Airport transp...  Specialty lodging
# 1276  (Kids Activities, Free parking, Airport transp...        B&Bs / Inns
# 1277                                                 ()  Specialty lodging
#
#                Location Numerator Denominator
# 0          Cidade Velha         1           9
# 1                 Praia         1          20
# 2             Boa Vista         4          30
# 3             Boa Vista         3          30
# 4     Cha das Caldeiras         1           7
# ...                 ...       ...         ...
# 1273   Sekondi-Takoradi         4          33
# 1274              Accra        74         363
# 1275         Bolgatanga         3          19
# 1276           Techiman         1          18
# 1277              Accra        50         337
#
# [35836 rows x 32 columns]

# %%
# data.to_csv(r"E:\Documents\data science\Capstone\data1")

# %%
from pandas_profiling import ProfileReport

# %%
import pandas_profiling

# %%
profile_trip = pandas_profiling.ProfileReport(df)
profile_trip.to_file("df.html")
